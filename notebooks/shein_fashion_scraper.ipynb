# %%
import pandas as pd
import requests

# %%
json_data = {'name': 'Ozzy Osbourne',
 'gender': 'Men',
 'hat': 'Wide-brimmed hats, Fedora hats, Top hats',
 'glasses': 'Round sunglasses, Aviator sunglasses, Rectangular glasses',
 'jewelry': 'Cross necklaces, Studded bracelets, Skull rings, Chain necklaces',
 'tops': 'Graphic tees, Leather jackets, Denim vests, Button-up shirts with bold prints',
 'pants': 'Black skinny jeans, Leather pants, Distressed denim, Cargo pants',
 'shoes': 'Combat boots, High-top sneakers, Loafers, Cowboy boots',
 'colors': 'Black, Dark shades of red, Purple, Silver, White',
 'conclusion': "Ozzy Osbourne's style is characterized by a mix of rock and roll and gothic influences."
               " Encourage your costumer to experiment with bold graphic tees, leather jackets, and black skinny jeans"
               " to capture Ozzy's edgy vibe. Accessorize with studded bracelets, cross necklaces, "
               "and skull rings. Opt for dark shades of red, purple, and silver to complement the black and white color scheme."
             }

# %%
import requests
product_name = 'Fedora hats'
men = 202
women = 443
gender = men
colors = ['Black','Red','Purple', 'Silver','White']
import requests

cookies = {
    'cookieId': 'C3EB5523_FD86_E2D4_7D1C_B9DFEFB535C3',
    'originOtherId': '2582776306',
    'country': 'IL',
    'countryId': '105',
    '_gcl_aw': 'GCL.1687094185.Cj0KCQjw1rqkBhCTARIsAAHz7K386HraqSIwpSztVjfoHoWFDcJHroP-p9fBYijcSk8cTzb78tAx-zEaAo86EALw_wcB',
    '_gcl_au': '1.1.433664629.1687094185',
    'language': 'en',
    'cdn_key': 'illang%3Dilen',
    'sessionID_shein': 's%3AsE-8cxXOv-ubS3ZqpeuvmPMNN5yzuw9P.1smA7Apm4RbJ1hLnx4YUBC5xPea%2FQJLHml8YaOnR1oI',
    'RESOURCE_ADAPT_WEBP': '1',
    'WEB_UGID_INIT': '1',
    '_csrf': 'Ew5vYWmDMHbt92FurFJk9WAL',
    'revisit_canshow': '1',
    'have_show': '1',
    'jump_to_il': '1',
    'no_pop_up_il': '1',
    'hideCoupon': '1',
    'hideCouponWithRequest': '1',
    'hideCouponId_time': '9051915_1',
    'SWITCH_LANGUAGE_GUIDE_ID': 'C3EB5523_FD86_E2D4_7D1C_B9DFEFB535C3',
    'smidV2': '20230707160117f02cb9f015510e88e2e71a98cc6d95e1000e717a9eb311090',
    'cate_channel_type': '2',
    'ssrAbt': 'typeBtype%3DAtype%3DBrule%3D1727_1766_767%3ABis_pde%3D3%26rule_id_120%3Drec_ver%3AS120V3.0%26rule_id_121%3Drec_ver%3AS121V2.1ZrangedetailtypelALogisticsTimeASizeTipsBUnderPriceFeedsoffUnderPriceShowASameLabelbannerConnetlabelAGroupsameA3PsellerdeliveryshowdetailshowsellerinfonoshowgoodsPicAbBdiscountLabelcallnolimitstoreyesReportshowhideMall_1',
    'RESOURCE_ADAPT_DEVICE': 'width%3D1920%26height%3D1080%26dpr%3D1%26mobile%3D0%26ios%3D0',
    'OptanonConsent': 'isIABGlobal=false&datestamp=Fri+Jul+07+2023+16%3A33%3A15+GMT%2B0300+(Israel+Daylight+Time)&version=6.13.0&hosts=&consentId=9db75548-292e-4bcf-a6d1-da714e728314&interactionCount=1&landingPath=https%3A%2F%2Fus.shein.com%2FSHEIN-EZwear-Solid-Elastic-Waist-Slant-Pocket-Sweatpants-p-3308015-cat-2990.html&groups=C0001%3A1%2CC0002%3A1%2CC0003%3A1%2CC0004%3A1',
    'addressCookie': '%7B%22countryId%22%3A%22105%22%2C%22createdTime%22%3A1688739277076%2C%22isUserHandle%22%3A%221%22%2C%22siteUid%22%3A%22il%22%7D',
    '_abck': 'A4D5003E71B47CDD0A0237FFCC9836FC~0~...~-1~-1~-1',
    'bm_sz': 'BCE8DF6D0492A8464F4985A2861C6ED6~~3289409~3556145',
    'bi_session_id': 'bi_1688815954957_54547',
    'default_currency_expire': '1',
    'ftr_blst_1h': '1688815957320',
    'bm_mi': '831891F7F2A92E7B7C1CCB8D44CF79CB~~1',
    'bm_sv': '0068DBC58138C9D4646C4E848FB861AD~~1',
    'ak_bmsc': '2FFFD60AD8D141F47C94320DD6091913~000000000000000000000000000000~...',
    'forterToken': 'e6d545d74c334ac79a06b6f71fefac7b_1688816915947_18_dUAL43-mnts-a9-d4_17ck',
    'default_currency': 'ILS',
}

headers = {
    'authority': 'il.shein.com',
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'en-US,en;q=0.9',
    'cache-control': 'no-cache',
    # 'cookie': 'cookieId=C3EB5523_FD86_E2D4_7D1C_B9DFEFB535C3; originOtherId=2582776306; country=IL; countryId=105; _gcl_aw=GCL.1687094185.Cj0KCQjw1rqkBhCTARIsAAHz7K386HraqSIwpSztVjfoHoWFDcJHroP-p9fBYijcSk8cTzb78tAx-zEaAo86EALw_wcB; _gcl_au=1.1.433664629.1687094185; language=en; cdn_key=illang%3Dilen; sessionID_shein=s%3AsE-8cxXOv-ubS3ZqpeuvmPMNN5yzuw9P.1smA7Apm4RbJ1hLnx4YUBC5xPea%2FQJLHml8YaOnR1oI; RESOURCE_ADAPT_WEBP=1; WEB_UGID_INIT=1; _csrf=Ew5vYWmDMHbt92FurFJk9WAL; revisit_canshow=1; have_show=1; jump_to_il=1; no_pop_up_il=1; hideCoupon=1; hideCouponWithRequest=1; hideCouponId_time=9051915_1; SWITCH_LANGUAGE_GUIDE_ID=C3EB5523_FD86_E2D4_7D1C_B9DFEFB535C3; smidV2=20230707160117f02cb9f015510e88e2e71a98cc6d95e1000e717a9eb311090; cate_channel_type=2; ssrAbt=typeBtype%3DAtype%3DBrule%3D1727_1766_767%3ABis_pde%3D3%26rule_id_120%3Drec_ver%3AS120V3.0%26rule_id_121%3Drec_ver%3AS121V2.1ZrangedetailtypelALogisticsTimeASizeTipsBUnderPriceFeedsoffUnderPriceShowASameLabelbannerConnetlabelAGroupsameA3PsellerdeliveryshowdetailshowsellerinfonoshowgoodsPicAbBdiscountLabelcallnolimitstoreyesReportshowhideMall_1; RESOURCE_ADAPT_DEVICE=width%3D1920%26height%3D1080%26dpr%3D1%26mobile%3D0%26ios%3D0; OptanonConsent=isIABGlobal=false&datestamp=Fri+Jul+07+2023+16%3A33%3A15+GMT%2B0300+(Israel+Daylight+Time)&version=6.13.0&hosts=&consentId=9db75548-292e-4bcf-a6d1-da714e728314&interactionCount=1&landingPath=https%3A%2F%2Fus.shein.com%2FSHEIN-EZwear-Solid-Elastic-Waist-Slant-Pocket-Sweatpants-p-3308015-cat-2990.html&groups=C0001%3A1%2CC0002%3A1%2CC0003%3A1%2CC0004%3A1; addressCookie=%7B%22countryId%22%3A%22105%22%2C%22createdTime%22%3A1688739277076%2C%22isUserHandle%22%3A%221%22%2C%22siteUid%22%3A%22il%22%7D; _abck=A4D5003E71B47CDD0A0237FFCC9836FC~0~...~-1~-1~-1; bm_sz=BCE8DF6D0492A8464F4985A2861C6ED6~~3289409~3556145; bi_session_id=bi_1688815954957_54547; default_currency_expire=1; ftr_blst_1h=1688815957320; bm_mi=831891F7F2A92E7B7C1CCB8D44CF79CB~~1; bm_sv=0068DBC58138C9D4646C4E848FB861AD~~1; ak_bmsc=2FFFD60AD8D141F47C94320DD6091913~000000000000000000000000000000~...; forterToken=e6d545d74c334ac79a06b6f71fefac7b_1688816915947_18_dUAL43-mnts-a9-d4_17ck; default_currency=ILS',
    'pragma': 'no-cache',
    'referer': 'https://il.shein.com/pdsearch/Leather%20jackets/?attr_values=Green-Purple-Yellow-Blue&ici=s1%60EditSearch%60Leather%20jackets%60_fb%60d0%60PageSearchResult&search_source=1&search_type=all&src_identifier=st%3D2%60sc%3DLeather%20jackets%60sr%3D0%60ps%3D1&src_module=search&src_tab_page_id=page_search1688816656507&page=1&attr_ids=27_81-27_334-27_2566-27_1000133-27_536-27_1000117-27_330-27_762-27_1000111-27_118-27_1000112-27_1000120-27_1000134&exc_attr_id=27',
    'sec-ch-ua': '"Not.A/Brand";v="8", "Chromium";v="114", "Google Chrome";v="114"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'uber-trace-id': 'ff50b6ca892e3acf:ff50b6ca892e3acf:0:0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36',
    'x-csrf-token': '0CbZCgOO-YFF4b3IuxhhKOervKG2qVNaStis',
    'x-requested-with': 'XMLHttpRequest',
}

params = {
    '_ver': '1.1.8',
    '_lang': 'en',
    'type': 'search',
    'routeId': {product_name},
    'page': '1',
    'ici': 's1`EditSearch{product_name}_fb`d0`PageSearchResult',
    'search_source': '1',
    'search_type': 'all',
    'src_identifier': 'st=2`sc{product_name}sr=0`ps=1',
    'src_module': 'search',
    'src_tab_page_id': 'page_search1688816656507',
    # 'child_cat_id':f'{gender}6',
    'attr_values': '.-'.join(colors),
    'attr_ids': '27_81-27_334-27_2566-27_1000133-27_536-27_1000117-27_330-27_762-27_1000111-27_118-27_1000112-27_1000120-27_1000134',
    'exc_attr_id': '27',
    'requestType': 'refresh',
}

response = requests.get('https://il.shein.com/api/productList/info/get', params=params, cookies=cookies, headers=headers)

# %%
result = response.json()
result
# item= result['goods'][0]
# item
# url_template = 'https://il.shein.com/{goods_url_name}-p-{goods_id}-cat-{cat_id}.html?src_identifier={src_identifier}&attr_ids=27_81-27_334-27_2566-27_1000133-27_536-27_1000117-27_330-27_762-27_1000111-27_118-27_1000112-27_1000120-27_1000134&mallCode=1'

# # Inside the for loop where you process each item in the response
# goods_id = item['goods_id']
# cat_id = item['cat_id']
# goods_url_name = item['goods_url_name']
# print(goods_url_name)
# src_identifier = params['src_identifier']

# # # Construct the URL using the template
# url = url_template.format(goods_url_name=goods_url_name, goods_id=goods_id, cat_id=cat_id, src_identifier=src_identifier)
# url
# Out:
# {'cccConfig': {'pcStandardView': {'goodsNameLine': 1}},
#  'relateSearchWords': [],
#  'filterAbtParam': {'currentId': '1772',
#   'value': 'AttrAndCat:1772',
#   'fieldName': 'search_attr_cat_rule',
#   'abt': {'child': [],
#    'p': {'767': '',
#     '1727': '',
#     '1934': '',
#     '2043': '',
#     '3301': '',
#     '3345': '',
#     '00310422': '',
#     '00856968': '',
#     '006113879': '',
#     '00815022': '',
#     'CCCdefault': ''},
#    'param': {'767': '',
#     '1727': '',
#     '1934': '',
#     '2043': '',
#     '3301': '',
#     '3345': '',
#     '00310422': '',
#     '00856968': '',
#     '006113879': '',
#     '00815022': '',
#     'CCCdefault': ''},
#    'version': 'v4',
#    'poskey': 'listFilterAbt',
#    'posKey': 'listFilterAbt',
#    'sceneStr': 'listFilterAbt'}},
#  'cccListOperation': {'pc_feedback_entry': {'abtBranch': '',
#    'content': [{'content': {'blockName': '1',
#       'name': 'searchfeedbacknew',
#       'id': 'pc_4hwvd67a0ds',
#       'type': 'FEEDBACK_ENTRY_COMPONENT',
#       'props': {'items': [{'hrefType2': '',
#          'surveyURL': {'shein_host': 'https://api-shein.shein.com/h5/survey/ukfeedback',
#           'romwe_host': 'https://api-romwe.romwe.com/h5/survey/ukfeedback'},
#          'catUrl': '/en-feedback',
#          'biContentList': 'en-feedback',
#          'adp': '',
#          'relativeUrl': '/en-feedback',
#          'selectTypeId': '',
#          'additionalConfig': {'immersive': '0', 'anchor': ''},
#          'hrefTarget': 'en-feedback',
#          'hrefType': 'survey',
#          'failCheck': False,
#          'text': "Didn't find what you're looking for?",
#          'skuTopping': ''}],
#        'style': {'accurateStatus': '0', 'type': 'FEEDBACK_ENTRY_COMPONENT'}}},
#      'oper_id': '53',
#      'oper_key': 'FEEDBACK_ENTRY_COMPONENT',
#      'oper_name': 'FeedbackEntry'}],
#    'disable_cache': 0,
#    'end_time': '1830268800',
#    'id': '6688047',
#    'module': 'list',
#    'sceneKey': 'pc_feedback_entry',
#    'sceneName': 'FeedbackEntry',
#    'scene_id': '17',
#    'scene_name': 'FeedbackEntry',
#    'start_time': '1644388632'}},
#  'filterTsps': [],
#  'hotFilterAttrs': {'27': '27_118-27_562-27_1000112-27_1000114-27_1000116-27_1000120-27_1000134-27_364-27_513-27_2427-27_1000115-27_1000123-27_1000128',
#   '73': '73_515-73_163',
#   '109': '109_1923-109_1926',
#   '160': '160_212-160_747'},
#  'cloudTags': [],
#  'filterAttrs': [{'attr_id': 27,
#    'attr_name': 'Color',
#    'attr_name_en': 'Color',
#    'show_group': True,
#    'groups': [{'group_id': '8',
#      'group_name': 'Blue',
#      'group_name_en': 'Blue',
#      'group_image': 'http://img.ltwebstatic.com/images3_pi/2020/03/30/1585556301bc3664cc0e59b223bf78e4155f30ff0b.jpg',
#      'attr_filter': '27_118-27_1000112-27_1000120-27_1000134',
#      'attr_values': [{'attr_value': 'Blue',
#        'attr_value_en': 'Blue',
#        'attr_filter': '27_118',
#        'attr_value_id': 118},
#       {'attr_value': 'Baby Blue',
#        'attr_value_en': 'Baby Blue',
#        'attr_filter': '27_1000112',
#        'attr_value_id': 1000112},
#       {'attr_value': 'Teal Blue',
#        'attr_value_en': 'Teal Blue',
#        'attr_filter': '27_1000120',
#        'attr_value_id': 1000120},
#       {'attr_value': 'Navy Blue',
#        'attr_value_en': 'Navy Blue',
#        'attr_filter': '27_1000134',
#        'attr_value_id': 1000134}],
#      'attr_id': 27,
#      'isSelected': True},
#     {'group_id': '3',
#      'group_name': 'Green',
#      'group_name_en': 'Green',
#      'group_image': 'http://img.ltwebstatic.com/images3_pi/2020/03/30/15855564343707ae1547770b64d8a08fde15076d18.jpg',
#      'attr_filter': '27_81-27_334-27_2566-27_1000133',
#      'attr_values': [{'attr_value': 'Army Green',
#        'attr_value_en': 'Army Green',
#        'attr_filter': '27_81',
#        'attr_value_id': 81},
#       {'attr_value': 'Green',
#        'attr_value_en': 'Green',
#        'attr_filter': '27_334',
#        'attr_value_id': 334},
#       {'attr_value': 'Dark Green',
#        'attr_value_en': 'Dark Green',
#        'attr_filter': '27_2566',
#        'attr_value_id': 2566},
#       {'attr_value': 'Olive Green',
#        'attr_value_en': 'Olive Green',
#        'attr_filter': '27_1000133',
#        'attr_value_id': 1000133}],
#      'attr_id': 27,
#      'isSelected': True},
#     {'group_id': '9',
#      'group_name': 'Purple',
#      'group_name_en': 'Purple',
#      'group_image': 'http://img.ltwebstatic.com/images3_pi/2020/03/30/158555664362acf943db9d324e60e9a112625dfc3e.jpg',
#      'attr_filter': '27_536-27_1000117',
#      'attr_values': [{'attr_value': 'Purple',
#        'attr_value_en': 'Purple',
#        'attr_filter': '27_536',
#        'attr_value_id': 536},
#       {'attr_value': 'Lilac Purple',
#        'attr_value_en': 'Lilac Purple',
#        'attr_filter': '27_1000117',
#        'attr_value_id': 1000117}],
#      'attr_id': 27,
#      'isSelected': True},
#     {'group_id': '12',
#      'group_name': 'Yellow',
#      'group_name_en': 'Yellow',
#      'group_image': 'http://img.ltwebstatic.com/images3_pi/2020/03/30/15855567509ceff4ce13de7e8706a63fad7ee459d5.jpg',
#      'attr_filter': '27_330-27_762-27_1000111',
#      'attr_values': [{'attr_value': 'Gold',
#        'attr_value_en': 'Gold',
#        'attr_filter': '27_330',
#        'attr_value_id': 330},
#       {'attr_value': 'Yellow',
#        'attr_value_en': 'Yellow',
#        'attr_filter': '27_762',
#        'attr_value_id': 762},
#       {'attr_value': 'Mustard Yellow',
#        'attr_value_en': 'Mustard Yellow',
#        'attr_filter': '27_1000111',
#        'attr_value_id': 1000111}],
#      'attr_id': 27,
#      'isSelected': True}],
#    'attr_values': [],
#    'selectedNum': 4,
#    'isShowChild': 1,
#    'lastSelectedIndex': 3,
#    'show_group_txt': False}],
#  'mergeFilterAttr': None,
#  'goods': [],
#  'filterPrices': {'max_price': 839, 'min_price': 9, 'isPlusSize': False},
#  'filterCates': {'isShowChild': 1,
#   'children': [{'cat_id': '2031',
#     'parent_id': '0',
#     'cat_url_name': 'Kids',
#     'cat_name': 'Kids',
#     'isSelected': False,
#     'isShowChild': 0,
#     'lastSelectedIndex': -1,
#     'children': [{'cat_id': '2022',
#       'parent_id': '2031',
#       'cat_url_name': 'Kids Accessories',
#       'cat_name': 'Kids Accessories',
#       'isSelected': False,
#       'isShowChild': 0,
#       'lastSelectedIndex': -1,
#       'children': [{'cat_id': '4799',
#         'parent_id': '2022',
#         'cat_url_name': 'Baby & Kids Hats',
#         'cat_name': 'Baby & Kids Hats',
#         'isSelected': False,
#         'isShowChild': 0,
#         'lastSelectedIndex': -1}]}]},
#    {'cat_id': '3631',
#     'parent_id': '0',
#     'cat_url_name': 'Apparel Accessories',
#     'cat_name': 'Apparel Accessories',
#     'isSelected': False,
#     'isShowChild': 0,
#     'lastSelectedIndex': -1,
#     'children': [{'cat_id': '1765',
#       'parent_id': '3631',
#       'cat_url_name': 'Women Accessories',
#       'cat_name': 'Women Accessories',
#       'isSelected': False,
#       'isShowChild': 0,
#       'lastSelectedIndex': -1,
#       'children': [{'cat_id': '3013',
#         'parent_id': '1765',
#         'cat_url_name': 'Women Hair Accessories',
#         'cat_name': 'Women Hair Accessories',
#         'isSelected': False,
#         'isShowChild': 0,
#         'lastSelectedIndex': -1,
#         'children': [{'cat_id': '1778',
#           'parent_id': '3013',
#           'cat_url_name': 'Headbands',
#           'cat_name': 'Headbands',
#           'isSelected': False,
#           'isShowChild': 0,
#           'lastSelectedIndex': -1}]},
#        {'cat_id': '3630',
#         'parent_id': '1765',
#         'cat_url_name': 'Women Hats',
#         'cat_name': 'Women Hats',
#         'isSelected': False,
#         'isShowChild': 0,
#         'lastSelectedIndex': -1,
#         'children': [{'cat_id': '1772',
#           'parent_id': '3630',
#           'cat_url_name': 'Women Baseball Cap',
#           'cat_name': 'Women Baseball Cap',
#           'isSelected': False,
#           'isShowChild': 0,
#           'lastSelectedIndex': -1},
#          {'cat_id': '5894',
#           'parent_id': '3630',
#           'cat_url_name': 'Women Hat set',
#           'cat_name': 'Women Hat set',
#           'isSelected': False,
#           'isShowChild': 0,
#           'lastSelectedIndex': -1},
#          {'cat_id': '5895',
#           'parent_id': '3630',
#           'cat_url_name': 'Women Other Hats',
#           'cat_name': 'Women Other Hats',
#           'isSelected': False,
#           'isShowChild': 0,
#           'lastSelectedIndex': -1},
#          {'cat_id': '5898',
#           'parent_id': '3630',
#           'cat_url_name': 'Women Funny Hat',
#           'cat_name': 'Women Funny Hat',
#           'isSelected': False,
#           'isShowChild': 0,
#           'lastSelectedIndex': -1},
#          {'cat_id': '5900',
#           'parent_id': '3630',
#           'cat_url_name': 'Women Fedora Hat',
#           'cat_name': 'Women Fedora Hat',
#           'isSelected': False,
#           'isShowChild': 0,
#           'lastSelectedIndex': -1},
#          {'cat_id': '5903',
#           'parent_id': '3630',
#           'cat_url_name': 'Women Straw Hat',
#           'cat_name': 'Women Straw Hat',
#           'isSelected': False,
#           'isShowChild': 0,
#           'lastSelectedIndex': -1},
#          {'cat_id': '5905',
#           'parent_id': '3630',
#           'cat_url_name': 'Women Bucket Hat',
#           'cat_name': 'Women Bucket Hat',
#           'isSelected': False,
#           'isShowChild': 0,
#           'lastSelectedIndex': -1}]}]},
#      {'cat_id': '2027',
#       'parent_id': '3631',
#       'cat_url_name': 'Men Accessories',
#       'cat_name': 'Men Accessories',
#       'isSelected': False,
#       'isShowChild': 0,
#       'lastSelectedIndex': -1,
#       'children': [{'cat_id': '5877',
#         'parent_id': '2027',
#         'cat_url_name': 'Men Hats',
#         'cat_name': 'Men Hats',
#         'isSelected': False,
#         'isShowChild': 0,
#         'lastSelectedIndex': -1,
#         'children': [{'cat_id': '5879',
#           'parent_id': '5877',
#           'cat_url_name': 'Men Other Hats',
#           'cat_name': 'Men Other Hats',
#           'isSelected': False,
#           'isShowChild': 0,
#           'lastSelectedIndex': -1},
#          {'cat_id': '5888',
#           'parent_id': '5877',
#           'cat_url_name': 'Men Fedora Hat',
#           'cat_name': 'Men Fedora Hat',
#           'isSelected': False,
#           'isShowChild': 0,
#           'lastSelectedIndex': -1},
#          {'cat_id': '5892',
#           'parent_id': '5877',
#           'cat_url_name': 'Men Straw Hat',
#           'cat_name': 'Men Straw Hat',
#           'isSelected': False,
#           'isShowChild': 0,
#           'lastSelectedIndex': -1},
#          {'cat_id': '5893',
#           'parent_id': '5877',
#           'cat_url_name': 'Men Bucket Hat',
#           'cat_name': 'Men Bucket Hat',
#           'isSelected': False,
#           'isShowChild': 0,
#           'lastSelectedIndex': -1}]}]}]},
#    {'cat_id': '3634',
#     'parent_id': '0',
#     'cat_url_name': 'Jewelry & Watches',
#     'cat_name': 'Jewelry & Watches',
#     'isSelected': False,
#     'isShowChild': 0,
#     'lastSelectedIndex': -1,
#     'children': [{'cat_id': '3632',
#       'parent_id': '3634',
#       'cat_url_name': "Women's Fashion Jewelry",
#       'cat_name': "Women's Fashion Jewelry",
#       'isSelected': False,
#       'isShowChild': 0,
#       'lastSelectedIndex': -1,
#       'children': [{'cat_id': '1777',
#         'parent_id': '3632',
#         'cat_url_name': "Women's Brooches",
#         'cat_name': "Women's Brooches",
#         'isSelected': False,
#         'isShowChild': 0,
#         'lastSelectedIndex': -1}]}]}],
#   'lastSelectedIndex': -1},
#  'selectedCate': [],
#  'selectedTsps': [],
#  'selectedAttrs': [{'group_id': '8',
#    'group_name': 'Blue',
#    'group_name_en': 'Blue',
#    'group_image': 'http://img.ltwebstatic.com/images3_pi/2020/03/30/1585556301bc3664cc0e59b223bf78e4155f30ff0b.jpg',
#    'attr_filter': '27_118-27_1000112-27_1000120-27_1000134',
#    'attr_values': [{'attr_value': 'Blue',
#      'attr_value_en': 'Blue',
#      'attr_filter': '27_118',
#      'attr_value_id': 118},
#     {'attr_value': 'Baby Blue',
#      'attr_value_en': 'Baby Blue',
#      'attr_filter': '27_1000112',
#      'attr_value_id': 1000112},
#     {'attr_value': 'Teal Blue',
#      'attr_value_en': 'Teal Blue',
#      'attr_filter': '27_1000120',
#      'attr_value_id': 1000120},
#     {'attr_value': 'Navy Blue',
#      'attr_value_en': 'Navy Blue',
#      'attr_filter': '27_1000134',
#      'attr_value_id': 1000134}],
#    'attr_id': 27,
#    'isSelected': True},
#   {'group_id': '3',
#    'group_name': 'Green',
#    'group_name_en': 'Green',
#    'group_image': 'http://img.ltwebstatic.com/images3_pi/2020/03/30/15855564343707ae1547770b64d8a08fde15076d18.jpg',
#    'attr_filter': '27_81-27_334-27_2566-27_1000133',
#    'attr_values': [{'attr_value': 'Army Green',
#      'attr_value_en': 'Army Green',
#      'attr_filter': '27_81',
#      'attr_value_id': 81},
#     {'attr_value': 'Green',
#      'attr_value_en': 'Green',
#      'attr_filter': '27_334',
#      'attr_value_id': 334},
#     {'attr_value': 'Dark Green',
#      'attr_value_en': 'Dark Green',
#      'attr_filter': '27_2566',
#      'attr_value_id': 2566},
#     {'attr_value': 'Olive Green',
#      'attr_value_en': 'Olive Green',
#      'attr_filter': '27_1000133',
#      'attr_value_id': 1000133}],
#    'attr_id': 27,
#    'isSelected': True},
#   {'group_id': '9',
#    'group_name': 'Purple',
#    'group_name_en': 'Purple',
#    'group_image': 'http://img.ltwebstatic.com/images3_pi/2020/03/30/158555664362acf943db9d324e60e9a112625dfc3e.jpg',
#    'attr_filter': '27_536-27_1000117',
#    'attr_values': [{'attr_value': 'Purple',
#      'attr_value_en': 'Purple',
#      'attr_filter': '27_536',
#      'attr_value_id': 536},
#     {'attr_value': 'Lilac Purple',
#      'attr_value_en': 'Lilac Purple',
#      'attr_filter': '27_1000117',
#      'attr_value_id': 1000117}],
#    'attr_id': 27,
#    'isSelected': True},
#   {'group_id': '12',
#    'group_name': 'Yellow',
#    'group_name_en': 'Yellow',
#    'group_image': 'http://img.ltwebstatic.com/images3_pi/2020/03/30/15855567509ceff4ce13de7e8706a63fad7ee459d5.jpg',
#    'attr_filter': '27_330-27_762-27_1000111',
#    'attr_values': [{'attr_value': 'Gold',
#      'attr_value_en': 'Gold',
#      'attr_filter': '27_330',
#      'attr_value_id': 330},
#     {'attr_value': 'Yellow',
#      'attr_value_en': 'Yellow',
#      'attr_filter': '27_762',
#      'attr_value_id': 762},
#     {'attr_value': 'Mustard Yellow',
#      'attr_value_en': 'Mustard Yellow',
#      'attr_filter': '27_1000111',
#      'attr_value_id': 1000111}],
#    'attr_id': 27,
#    'isSelected': True}],
#  'cat_info': {'channel_id': 1,
#   'keywords': 'Fedora hats',
#   '_ver': '1.1.8',
#   '_lang': 'en',
#   'type': 'search',
#   'routeId': 'Fedora hats',
#   'page': '1',
#   'ici': 's1`EditSearch{product_name}_fb`d0`PageSearchResult',
#   'search_source': '1',
#   'search_type': 'all',
#   'src_identifier': 'st=2`sc{product_name}sr=0`ps=1',
#   'src_module': 'search',
#   'src_tab_page_id': 'page_search1688816656507',
#   'child_cat_id': '2026',
#   'attr_values': 'Black.-Red.-Purple.-Silver.-White',
#   'attr_ids': '27_81-27_334-27_2566-27_1000133-27_536-27_1000117-27_330-27_762-27_1000111-27_118-27_1000112-27_1000120-27_1000134',
#   'exc_attr_id': '27',
#   'requestType': 'refresh',
#   'limit': 120,
#   'listCaller': 'PC:OriginList',
#   'fromNew': True,
#   'pageName': 'page_search',
#   'originalUrl': '/api/productList/info/get?_ver=1.1.8&_lang=en&type=search&routeId=Fedora+hats&page=1&ici=s1%60EditSearch%7Bproduct_name%7D_fb%60d0%60PageSearchResult&search_source=1&search_type=all&src_identifier=st%3D2%60sc%7Bproduct_name%7Dsr%3D0%60ps%3D1&src_module=search&src_tab_page_id=page_search1688816656507&child_cat_id=2026&attr_values=Black.-Red.-Purple.-Silver.-White&attr_ids=27_81-27_334-27_2566-27_1000133-27_536-27_1000117-27_330-27_762-27_1000111-27_118-27_1000112-27_1000120-27_1000134&exc_attr_id=27&requestType=refresh',
#   'currency': 'ILS',
#   'sortScene': 'SearchPageSort'},
#  'fhContext': {},
#  'googleContext': None,
#  'templateType': 'goods_list',
#  'sum': 0,
#  'sumForPage': 0,
#  'trace_id': '',
#  'goodsCrowId': {'plus_strategy': 0,
#   'prefer_cate_1_id': None,
#   'pay_score_level': None,
#   'old_customer_flag': None},
#  'request_ext': {'queryProcess': 'correctManual_0-divided_0-secLang_0-correct_0',
#   'keyword': 'Fedora hats'},
#  'nlkt': 109,
#  'pdeCacheControl': 0,
#  'searchKeywords': {'origin_words': 'Fedora hats',
#   'origin_total': 0,
#   'suggest_words': '',
#   'suggest_total': 0,
#   'is_suggest_res': 0,
#   'is_force': 0,
#   'double_lang_correct': False}}
